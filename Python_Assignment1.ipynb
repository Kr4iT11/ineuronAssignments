# %% [markdown]
# # 1 In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

# %% [markdown]
# * : Expressions
# - : Expressions
# / : Expressions
# ----------------------------------------------------------------------------
# 'hello' : value
# -87.8 : value
# 6 : value

# %% [markdown]
# # 2 What is the difference between string and variable?

# %% [markdown]
# A Variable is a store of information, and a String is a type of information you would store in a Variable. A String is usually words, enclosed with ""
# for example
#
# s = "My Name is Gursimran"
# where s can be called as a variable but its type of string variable because it is holding a text form of data

# %% [markdown]
# # 3.Describe three different data types.

# %% [markdown]
# Three different types of data types are integer,complex,string
# Integers : Integers are basically the whole numbers (can be positive or negative but not decimal values)
# it is represented by int class in python
# e.g  : my_val = 1,
# String : String is a collection of one or more characters put in between quotes It is represented by str class
# e.g : my_str_val = "My Name is gursimran"
# Complex : complex datatypes are basically used to store the complex type values in a variable
# it is represented by complex class
# e.g : complex_var = 5 + 6j where 5 is a real part and 6 is imaginary part

# %% [markdown]
# # 4.What is an expression made up of? What do all expressions do?

# %% [markdown]
# Expressions are basically evavluates a values
# Expression is a combination of variables, operations and values that result value.
# for e.g
# x + y
# x * y

# %% [markdown]
# # 5.This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# Statements represent an action or command e.g print statements, assignment statements.
# in the above question spam = 10 is a statement
# the main  difference between an expression and a statement is that statement represents an action or a command where as expression evavluates a value
# e.g for expression
# x + y
# 5 * 10
# e.g for statements
# print(x*y)

# %% [markdown]
# # 6 After running the following code, what does the variable bacon contain?

# %%
bacon = 22
bacon + 1
# Out:
# 23

# %% [markdown]
# # 7 What should the values of the following two terms be?

# %%
'spam' + 'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# # 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# A variable is associated with space in the computer memory that can hold a value
# so for those reasons the variable cannot start with a number
# so eggs

# %% [markdown]
# # 9 What three functions can be used to get the integer, floating-point number, or string version of a value?

# %%
int()
float()
str()
# Out:
# ''

# %% [markdown]
# # 10 Why does this expression cause an error? How can you fix it ? 'i have eaten' + 99 + 'burritos'

# %%
#The reason is simple because you can only concantinate string with string not a integer
#you cannot concatinate string with integer value 
#the best way to solve this is make 99 as string
val = ' 99 '
'i have eaten' + val + 'burritos'
# Out:
# 'i have eaten 99 burritos'

# %%
#or you can also do it like this 
'i have eaten' + ' 99 ' + 'burritos'
# Out:
# 'i have eaten 99 burritos'

# %%
#one more way to do it as 
'i have eaten '+ str(99) + ' burritos'
# Out:
# 'i have eaten 99 burritos'
